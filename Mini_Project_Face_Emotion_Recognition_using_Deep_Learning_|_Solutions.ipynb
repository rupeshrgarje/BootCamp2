# %% [markdown]
# <a href="https://colab.research.google.com/github/rupeshrgarje/BootCamp2/blob/main/Mini_Project_Face_Emotion_Recognition_using_Deep_Learning_%7C_Solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📌 Step 1: Install Required Libraries

# %%
# !pip install kaggle --quiet
# !pip install tensorflow matplotlib seaborn --quiet

# %% [markdown]
# # 📌 Step 2: Upload Your Kaggle API Token
# Go to https://www.kaggle.com/settings
#
# Scroll down to “API” and click “Create New API Token”
#
# Upload the kaggle.json file in Colab

# %%
kaggle_api = '/content/drive/MyDrive/Black Elephant/Kaggle_API/kaggle.json'

# %%
# Copy Kaggle API Key from Drive to .kaggle/
# !mkdir -p ~/.kaggle
# !cp /content/drive/MyDrive/Black\ Elephant/Kaggle_API/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# # 📌 Step 3: Download FER2013 Dataset from Kaggle

# %%
# !kaggle datasets download -d msambare/fer2013
# !unzip -q fer2013.zip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/msambare/fer2013
# License(s): DbCL-1.0
# Downloading fer2013.zip to /content
#   0% 0.00/60.3M [00:00<?, ?B/s]
# 100% 60.3M/60.3M [00:00<00:00, 1.31GB/s]

# %% [markdown]
# # 📌 Step 4: Set Up Image Data Loaders

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Base directory
train_dir = "/content/train"
test_dir = "/content/test"

# Create ImageDataGenerator with validation split
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2  # 20% of training data for validation
)

# Training generator (80% of train data)
train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(48, 48),
    batch_size=64,
    color_mode='grayscale',
    class_mode='categorical',
    subset='training',
    shuffle=True
)

# Validation generator (20% of train data)
val_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(48, 48),
    batch_size=64,
    color_mode='grayscale',
    class_mode='categorical',
    subset='validation',
    shuffle=True
)

# Test generator (no split needed)
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(48, 48),
    batch_size=64,
    color_mode='grayscale',
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 22968 images belonging to 7 classes.
# Found 5741 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# # 📌 Step 5: Build the CNN Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 1)),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(7, activation='softmax')  # 7 classes
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 46, 46, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 23, 23, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 23, 23, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 21, 21, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 10, 10, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 10, 10, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 6400)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       819,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 839,047 (3.20 MB)
#  Trainable params: 839,047 (3.20 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # 📌 Step 6: Train the Model

# %%
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=100
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - accuracy: 0.2508 - loss: 1.8175 - val_accuracy: 0.3818 - val_loss: 1.6220
# Epoch 2/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - accuracy: 0.3693 - loss: 1.6021 - val_accuracy: 0.4276 - val_loss: 1.5000
# Epoch 3/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.4166 - loss: 1.5074 - val_accuracy: 0.4538 - val_loss: 1.4169
# Epoch 4/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.4465 - loss: 1.4408 - val_accuracy: 0.4673 - val_loss: 1.4019
# Epoch 5/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.4646 - loss: 1.4028 - val_accuracy: 0.4837 - val_loss: 1.3326
# Epoch 6/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.4786 - loss: 1.3530 - val_accuracy: 0.4842 - val_loss: 1.3331
# Epoch 7/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.4950 - loss: 1.3204 - val_accuracy: 0.5036 - val_loss: 1.2984
# Epoch 8/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.5004 - loss: 1.2972 - val_accuracy: 0.5044 - val_loss: 1.2902
# Epoch 9/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.5124 - loss: 1.2668 - val_accuracy: 0.5166 - val_loss: 1.2649
# Epoch 10/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.5123 - loss: 1.2492 - val_accuracy: 0.5175 - val_loss: 1.2555
# Epoch 11/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - accuracy: 0.5345 - loss: 1.2228 - val_accuracy: 0.5220 - val_loss: 1.2467
# Epoch 12/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.5394 - loss: 1.1961 - val_accuracy: 0.5217 - val_loss: 1.2443
# Epoch 13/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.5475 - loss: 1.1844 - val_accuracy: 0.5213 - val_loss: 1.2478
# Epoch 14/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.5547 - loss: 1.1604 - val_accuracy: 0.5307 - val_loss: 1.2323
# Epoch 15/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - accuracy: 0.5701 - loss: 1.1285 - val_accuracy: 0.5260 - val_loss: 1.2497
# Epoch 16/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - accuracy: 0.5639 - loss: 1.1258 - val_accuracy: 0.5356 - val_loss: 1.2342
# Epoch 17/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - accuracy: 0.5746 - loss: 1.0955 - val_accuracy: 0.5396 - val_loss: 1.2183
# Epoch 18/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.5809 - loss: 1.0959 - val_accuracy: 0.5335 - val_loss: 1.2163
# Epoch 19/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - accuracy: 0.5862 - loss: 1.0730 - val_accuracy: 0.5335 - val_loss: 1.2275
# Epoch 20/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.5851 - loss: 1.0719 - val_accuracy: 0.5417 - val_loss: 1.2212
# Epoch 21/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.6014 - loss: 1.0427 - val_accuracy: 0.5471 - val_loss: 1.2178
# Epoch 22/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.6056 - loss: 1.0270 - val_accuracy: 0.5410 - val_loss: 1.2268
# Epoch 23/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.6058 - loss: 1.0232 - val_accuracy: 0.5405 - val_loss: 1.2274
# Epoch 24/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.6067 - loss: 1.0062 - val_accuracy: 0.5419 - val_loss: 1.2287
# Epoch 25/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.6198 - loss: 0.9767 - val_accuracy: 0.5424 - val_loss: 1.2413
# Epoch 26/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.6181 - loss: 0.9721 - val_accuracy: 0.5424 - val_loss: 1.2406
# Epoch 27/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - accuracy: 0.6199 - loss: 0.9720 - val_accuracy: 0.5395 - val_loss: 1.2502
# Epoch 28/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.6318 - loss: 0.9571 - val_accuracy: 0.5520 - val_loss: 1.2431
# Epoch 29/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.6308 - loss: 0.9409 - val_accuracy: 0.5452 - val_loss: 1.2420
# Epoch 30/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.6262 - loss: 0.9513 - val_accuracy: 0.5530 - val_loss: 1.2560
# Epoch 31/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - accuracy: 0.6495 - loss: 0.9107 - val_accuracy: 0.5403 - val_loss: 1.2394
# Epoch 32/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.6420 - loss: 0.9194 - val_accuracy: 0.5462 - val_loss: 1.2494
# Epoch 33/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.6517 - loss: 0.9071 - val_accuracy: 0.5515 - val_loss: 1.2588
# Epoch 34/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.6461 - loss: 0.9101 - val_accuracy: 0.5457 - val_loss: 1.2599
# Epoch 35/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.6465 - loss: 0.8942 - val_accuracy: 0.5438 - val_loss: 1.2646
# Epoch 36/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.6613 - loss: 0.8805 - val_accuracy: 0.5471 - val_loss: 1.2683
# Epoch 37/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.6576 - loss: 0.8777 - val_accuracy: 0.5475 - val_loss: 1.2858
# Epoch 38/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - accuracy: 0.6567 - loss: 0.8781 - val_accuracy: 0.5459 - val_loss: 1.2692
# Epoch 39/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.6558 - loss: 0.8779 - val_accuracy: 0.5433 - val_loss: 1.2909
# Epoch 40/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.6590 - loss: 0.8590 - val_accuracy: 0.5496 - val_loss: 1.2846
# Epoch 41/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - accuracy: 0.6723 - loss: 0.8322 - val_accuracy: 0.5457 - val_loss: 1.2919
# Epoch 42/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.6697 - loss: 0.8394 - val_accuracy: 0.5473 - val_loss: 1.2828
# Epoch 43/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - accuracy: 0.6715 - loss: 0.8388 - val_accuracy: 0.5443 - val_loss: 1.2948
# Epoch 44/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.6716 - loss: 0.8405 - val_accuracy: 0.5438 - val_loss: 1.2846
# Epoch 45/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - accuracy: 0.6767 - loss: 0.8155 - val_accuracy: 0.5482 - val_loss: 1.2917
# Epoch 46/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.6796 - loss: 0.8227 - val_accuracy: 0.5412 - val_loss: 1.3062
# Epoch 47/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.
100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.7322 - loss: 0.6917 - val_accuracy: 0.5523 - val_loss: 1.4215
# Epoch 81/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.7325 - loss: 0.6758 - val_accuracy: 0.5520 - val_loss: 1.4046
# Epoch 82/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.7386 - loss: 0.6593 - val_accuracy: 0.5523 - val_loss: 1.4118
# Epoch 83/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.7455 - loss: 0.6559 - val_accuracy: 0.5543 - val_loss: 1.4431
# Epoch 84/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.7475 - loss: 0.6525 - val_accuracy: 0.5532 - val_loss: 1.3936
# Epoch 85/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.7408 - loss: 0.6619 - val_accuracy: 0.5570 - val_loss: 1.4283
# Epoch 86/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.7439 - loss: 0.6607 - val_accuracy: 0.5532 - val_loss: 1.3976
# Epoch 87/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.7459 - loss: 0.6476 - val_accuracy: 0.5501 - val_loss: 1.4330
# Epoch 88/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.7363 - loss: 0.6645 - val_accuracy: 0.5527 - val_loss: 1.4160
# Epoch 89/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.7498 - loss: 0.6462 - val_accuracy: 0.5496 - val_loss: 1.3942
# Epoch 90/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.7443 - loss: 0.6468 - val_accuracy: 0.5529 - val_loss: 1.3910
# Epoch 91/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.7469 - loss: 0.6388 - val_accuracy: 0.5523 - val_loss: 1.4161
# Epoch 92/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.7492 - loss: 0.6414 - val_accuracy: 0.5478 - val_loss: 1.4337
# Epoch 93/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.7570 - loss: 0.6302 - val_accuracy: 0.5461 - val_loss: 1.4209
# Epoch 94/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.7491 - loss: 0.6304 - val_accuracy: 0.5522 - val_loss: 1.4086
# Epoch 95/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - accuracy: 0.7557 - loss: 0.6207 - val_accuracy: 0.5525 - val_loss: 1.4093
# Epoch 96/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.7508 - loss: 0.6345 - val_accuracy: 0.5562 - val_loss: 1.4312
# Epoch 97/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.7562 - loss: 0.6191 - val_accuracy: 0.5551 - val_loss: 1.4405
# Epoch 98/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.7556 - loss: 0.6233 - val_accuracy: 0.5550 - val_loss: 1.4462
# Epoch 99/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.7581 - loss: 0.6201 - val_accuracy: 0.5548 - val_loss: 1.4468
# Epoch 100/100
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.7588 - loss: 0.6180 - val_accuracy: 0.5513 - val_loss: 1.4383

# %% [markdown]
# # 📌 Step 7: Evaluate on Test Data

# %%
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.4885 - loss: 1.6383
# Test Accuracy: 0.5588

# %% [markdown]
# # 📌 Step 8: Plot Training and Validation Metrics

# %%
import matplotlib.pyplot as plt

# Accuracy
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Valid')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Loss
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Valid')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# # 📌 Step 9: Inference on a single image

# %%
class_labels = list(train_generator.class_indices.keys())

# %%
class_labels
# Out:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

# %%
import os

def predict_emotion(img_path):
    # Get actual class name from file path
    actual_label = os.path.basename(os.path.dirname(img_path))

    # Load and preprocess image
    img = image.load_img(img_path, color_mode='grayscale')
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0

    # Predict
    prediction = model.predict(img_array)
    predicted_class = np.argmax(prediction)
    predicted_label = class_labels[predicted_class]

    # Display image with actual & predicted label
    plt.imshow(img_array[0].squeeze(), cmap='gray')
    plt.title(f"Actual: {actual_label.capitalize()} | Predicted: {predicted_label.capitalize()}")
    plt.axis('off')
    plt.show()

# %%
predict_emotion("/content/test/happy/PrivateTest_13103594.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step

# %%
predict_emotion("/content/test/surprise/PrivateTest_13683211.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step

# %%
predict_emotion("/content/test/fear/PrivateTest_11014592.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step

# %%
predict_emotion("/content/test/sad/PrivateTest_10814167.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
